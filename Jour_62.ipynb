# %% [markdown]
# Sujet : Révision du fichier fasta

# %%
with open("sequence.fasta", "w") as f:
    f.write(">1 Chromosome 1\nATGCGTAC...")

with open("sequence.fasta", "r") as fichier:
    en_tete = fichier.readline()
    
    #Vérification pour voir si c'est bien un fichier fasta
    if en_tete.startswith(">"):
        print(f"C'est bien un fichier fasta.")
        print(f"Informations contenu dedans : {en_tete.strip()}")
