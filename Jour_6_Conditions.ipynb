# %%
longueur_adn = 150

if longueur_adn > 200:
    print(f"Séquence longue")
#ça marche comme ça aussi longueur=>100:
elif  200> longueur_adn >100 :
    print(f"Séquence moyenne")
else :
    print(f"Séquence courte")
# Out:
# Séquence moyenne
