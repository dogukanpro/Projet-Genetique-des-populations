# %% [markdown]
# Sujet : revision 1er mois

# %%
try:
    with open("sequence_occitanie.txt", "r") as fichier:
        contenu = fichier.read()
        adn = contenu.strip()
        
    print(f"Fichier lu avec succès !")
    print(f"Longueur de la séquence importée : {len(adn)} bases")

except FileNotFoundError:
    print("Erreur : Le fichier 'sequence_occitanie.txt' n'a pas été trouvé.")
