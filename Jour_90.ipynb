# %% [markdown]
# Sujet : révision premier mois (création fichier texte)

# %%
sequence = "ATGCGGGGCCTAA"
taux_gc = 61.5
localite = "Occitanie"

#Création et écriture du fichier
with open("rapport_genetique.txt", "w") as f:
    f.write("--- RAPPORT D'ANALYSE GÉNÉTIQUE ---\n")
    f.write(f"Origine : {localite}\n")
    f.write(f"Séquence : {sequence}\n")
    f.write(f"Taux de GC : {taux_gc}%\n")
    f.write("-----------------------------------\n")

print("Le fichier 'rapport_genetique.txt' a été fait avec succès !")
