# %% [markdown]
# La séquence d'ADN

# %%
sequences = "atgc", "ccgg", "ttaa"

# %% [markdown]
# La boucle for + Affichage

# %%
for s in sequences :
    majuscule = s.upper()
    taille = len(s)
    print(f"La séquence {majuscule} fait {taille} bases.")

print("Analyse terminée.")
# Out:
# La séquence ATGC fait 4 bases.
# La séquence CCGG fait 4 bases.
# La séquence TTAA fait 4 bases.
# Analyse terminée.
