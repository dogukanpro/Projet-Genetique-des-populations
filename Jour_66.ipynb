# %% [markdown]
# Sujet : Ecriture de fichier type excel

# %%
resultats = [
    {"nom": "Modern_Occitan_01", "gc": 42.5},
    {"nom": "Old_Occitan_01", "gc": 48.2},
    {"nom": "Modern_Occitan_02", "gc": 41.8}
]

with open("resultats_occitan.csv", "w") as f:
    for r in resultats:
        ligne = f"{r['nom']},{r['gc']}\n"
        f.write(ligne)
