# %% [markdown]
# Initialisation

# %%
table_genetique = {"ATT" : "Isoleucine","ATG" : "Méthionine", "GCA" : "Alanine" }

mon_codon = "GCA"

# %% [markdown]
# Affichage + utilisation bibliothèque, pour traduire codon d'ADN en acide aminé

# %%
resultat = table_genetique[mon_codon]
print(f"Le codon {mon_codon} code pour l'acide aminé : {resultat}")
# Out:
# Le codon GCA code pour l'acide aminé : Alanine
