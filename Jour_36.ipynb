# %% [markdown]
# Initialisation

# %%
reference_europe = "Europe de l'Ouest"

# %% [markdown]
# Le variable peuple est locale à la méthode afficher_analyser, on ne peut l'utiliser en dehors sans appeler la méthode, c'est le but du programme d'aujourd'hui de montrer cela

# %%
def afficher_analyse():
    peuple = "Celtes" 
    print(f"Analyse de la zone : {reference_europe}")
    print(f"Focus sur le peuple : {peuple}")

# %% [markdown]
# Affichage

# %%
afficher_analyse()
# Out:
# Analyse de la zone : Europe de l'Ouest
# Focus sur le peuple : Celtes
