# %% [markdown]
# Je fait une liste de genes

# %%
genes = ["MYC", "TP53", "BRCA1"]

# %% [markdown]
# J'accéde au deuxième gène de la liste

# %%
deuxieme_gene = genes[1]

# %% [markdown]
# J'ajoute une nouvelle gène dans la liste

# %%
genes.append("APOE")

# %% [markdown]
# Affichage

# %%
print(f"Ma liste contient {len(genes)} gènes.")
print(f"Voici la deuxième de la liste {deuxieme_gene}")
print(f"Voici la liste complète aprés le rajout d'un autre gène : {genes}")
# Out:
# Ma liste contient 4 gènes.
# Voici la deuxième de la liste TP53
# Voici la liste complète aprés le rajout d'un autre gène : ['MYC', 'TP53', 'BRCA1', 'APOE']
