# %% [markdown]
# Création de la bibliothèque

# %%
fossile = {"nom" :"Ankylosaurus", "lieu" : "Amérique", "age" : "65 000 000 d'années" }

# %% [markdown]
# Utilisation de la bibliothèque

# %%
print(f"Le fossile {fossile["nom"]} a été trouvé en {fossile["lieu"]} et date d'il y a {fossile["age"]}")
# Out:
# Le fossile Ankylosaurus a été trouvé en Amérique et date d'il y a 65 000 000 d'années
