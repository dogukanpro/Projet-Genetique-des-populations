# %% [markdown]
# Initialisation

# %%
nom_fichier = "adn_ancetre.txt"

# %% [markdown]
# Affichage(messages personnalisées d'erreur)

# %%
try:
    with open(nom_fichier, "r") as fichier:
        donnees = fichier.read()
        print(donnees)
except NameError:
    print("La variable n'est pas définie !")
except FileNotFoundError:
    print("Le fichier n'existe pas encore sur le disque.")
# Out:
# Le fichier n'existe pas encore sur le disque.
