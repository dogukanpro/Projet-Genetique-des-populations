# %% [markdown]
# Sujet : suite jour 90

# %%
nom_fichier = "donnees_occitanie_manquantes.txt"

try:
    with open(nom_fichier, "r") as f:
        data = f.read()
        print("Lecture fait")

except FileNotFoundError:
    print(f"Le fichier '{nom_fichier}' est introuvable.")

except Exception as e:
    #pour toute autre erreur
    print(f"Une erreur inconnue est survenue : {e}")
