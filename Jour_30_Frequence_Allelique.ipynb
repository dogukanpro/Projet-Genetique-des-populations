# %% [markdown]
# Intitalisation (regardons la frequence allelique d'une poopulation actuelle par rapport à une ancienne)

# %%
pop_actuelle = ["A", "A", "G", "A", "G", "A", "A", "A", "G", "A"]

# %%
pop_g = pop_actuelle.count("G")
total = len(pop_actuelle)
pourcentage = (nb_g / total) * 100

# %% [markdown]
# Affichage

# %%
print(f"Analyse de la population :")
print(f"Fréquence de l'allèle ancestral : {pourcentage}%")

# %% [markdown]
# Prenons par exemple 20% comme seuil

# %%
if pourcentage > 20:
    print("Résultat : Héritage significatif détecté.")
else:
    print("Résultat : Faible hérotage de cette population ancienne.")
